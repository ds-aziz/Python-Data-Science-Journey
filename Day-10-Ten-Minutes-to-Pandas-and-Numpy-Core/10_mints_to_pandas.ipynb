# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[us]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.740422  0.619768 -0.521959  1.007010
# 2013-01-02 -0.255496 -1.347615  0.666679  0.208676
# 2013-01-03  1.811245 -1.764546  0.448927 -1.395834
# 2013-01-04  0.450626 -0.824448 -0.624153 -0.947225
# 2013-01-05  0.698824  1.130257  1.090754 -0.384426
# 2013-01-06 -0.159491  0.020443 -0.628816 -0.204320

# %% [markdown]
# # Dictionary

# %%
# aziz is key value, 5.4 is key ki real value.

dict = {'Aziz':5.4, 'Nandlal':5.3}

dict
# Out:
# {'Aziz': 5.4, 'Nandlal': 5.3}

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[us]
# C           float32
# D             int32
# E          category
# F               str
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[us]
#  2   C       4 non-null      float32
#  3   D       4 non-null      int32
#  4   E       4 non-null      category
#  5   F       4 non-null      str
# dtypes: category(1), datetime64[us](1), float32(1), float64(1), int32(1), str(1)
# memory usage: 180.0 bytes

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.tail()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[us]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='str')

# %%
df.to_numpy()
# Out:
# array([[ 0.74042208,  0.61976838, -0.52195909,  1.00701022],
#        [-0.25549599, -1.34761524,  0.66667883,  0.20867614],
#        [ 1.81124511, -1.76454563,  0.4489269 , -1.39583351],
#        [ 0.45062639, -0.82444753, -0.62415321, -0.9472253 ],
#        [ 0.69882407,  1.13025672,  1.0907538 , -0.3844256 ],
#        [-0.15949114,  0.02044269, -0.62881608, -0.20432035]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.547688 -0.361023  0.071905 -0.286020
# std    0.749826  1.139244  0.756589  0.848751
# min   -0.255496 -1.764546 -0.628816 -1.395834
# 25%   -0.006962 -1.216823 -0.598605 -0.806525
# 50%    0.574725 -0.402002 -0.036516 -0.294373
# 75%    0.730023  0.469937  0.612241  0.105427
# max    1.811245  1.130257  1.090754  1.007010

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.740422   -0.255496    1.811245    0.450626    0.698824   -0.159491
# B    0.619768   -1.347615   -1.764546   -0.824448    1.130257    0.020443
# C   -0.521959    0.666679    0.448927   -0.624153    1.090754   -0.628816
# D    1.007010    0.208676   -1.395834   -0.947225   -0.384426   -0.204320

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.740422  0.619768 -0.521959  1.007010
# 2013-01-02 -0.255496 -1.347615  0.666679  0.208676
# 2013-01-03  1.811245 -1.764546  0.448927 -1.395834
# 2013-01-04  0.450626 -0.824448 -0.624153 -0.947225
# 2013-01-05  0.698824  1.130257  1.090754 -0.384426
# 2013-01-06 -0.159491  0.020443 -0.628816 -0.204320

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.007010 -0.521959  0.619768  0.740422
# 2013-01-02  0.208676  0.666679 -1.347615 -0.255496
# 2013-01-03 -1.395834  0.448927 -1.764546  1.811245
# 2013-01-04 -0.947225 -0.624153 -0.824448  0.450626
# 2013-01-05 -0.384426  1.090754  1.130257  0.698824
# 2013-01-06 -0.204320 -0.628816  0.020443 -0.159491

# %% [markdown]
# ## Assignment:
#
# # axis = 1 means ke hum column ko access kr rhy hai ya change kr rhy hai through the sort_index() function.
# # axis = 0 means ke hum rows ko access kr rhy hai ya change kr rhy hai through the sort_index() function.

# %%
df.sort_values(by='A')
# Out:
#                    A         B         C         D
# 2013-01-02 -0.255496 -1.347615  0.666679  0.208676
# 2013-01-06 -0.159491  0.020443 -0.628816 -0.204320
# 2013-01-04  0.450626 -0.824448 -0.624153 -0.947225
# 2013-01-05  0.698824  1.130257  1.090754 -0.384426
# 2013-01-01  0.740422  0.619768 -0.521959  1.007010
# 2013-01-03  1.811245 -1.764546  0.448927 -1.395834

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.740422  0.619768 -0.521959  1.007010
# 2013-01-02 -0.255496 -1.347615  0.666679  0.208676
# 2013-01-03  1.811245 -1.764546  0.448927 -1.395834
# 2013-01-04  0.450626 -0.824448 -0.624153 -0.947225
# 2013-01-05  0.698824  1.130257  1.090754 -0.384426
# 2013-01-06 -0.159491  0.020443 -0.628816 -0.204320

# %%
df['A']
# Out:
# 2013-01-01    0.740422
# 2013-01-02   -0.255496
# 2013-01-03    1.811245
# 2013-01-04    0.450626
# 2013-01-05    0.698824
# 2013-01-06   -0.159491
# Freq: D, Name: A, dtype: float64

# %%
df[['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.740422  0.619768
# 2013-01-02 -0.255496 -1.347615
# 2013-01-03  1.811245 -1.764546
# 2013-01-04  0.450626 -0.824448
# 2013-01-05  0.698824  1.130257
# 2013-01-06 -0.159491  0.020443

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.740422  0.619768 -0.521959  1.007010
# 2013-01-02 -0.255496 -1.347615  0.666679  0.208676
# 2013-01-03  1.811245 -1.764546  0.448927 -1.395834

# %%
df.shape
# Out:
# (6, 4)

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.740422  0.619768 -0.521959  1.007010
# 2013-01-02 -0.255496 -1.347615  0.666679  0.208676
# 2013-01-03  1.811245 -1.764546  0.448927 -1.395834
# 2013-01-04  0.450626 -0.824448 -0.624153 -0.947225
# 2013-01-05  0.698824  1.130257  1.090754 -0.384426
# 2013-01-06 -0.159491  0.020443 -0.628816 -0.204320

# %%
#indexing range in columns
df.iloc[:,0:2]
# Out:
#                    A         B
# 2013-01-01  0.740422  0.619768
# 2013-01-02 -0.255496 -1.347615
# 2013-01-03  1.811245 -1.764546
# 2013-01-04  0.450626 -0.824448
# 2013-01-05  0.698824  1.130257
# 2013-01-06 -0.159491  0.020443

# %%
#indexing range in rows
df.iloc[0:4, :] # iloc use hota hai index ko lock krne ke liye.
# Out:
#                    A         B         C         D
# 2013-01-01  0.740422  0.619768 -0.521959  1.007010
# 2013-01-02 -0.255496 -1.347615  0.666679  0.208676
# 2013-01-03  1.811245 -1.764546  0.448927 -1.395834
# 2013-01-04  0.450626 -0.824448 -0.624153 -0.947225

# %%
# loc indexing column wise hoti hai but Srings ke sath like name column ka name de kr.
# loc function simple loc ke liye use hoti hai kisi bhi column ya row ko but as a string call krke bula skty hai. 
df.loc[:,'A':'B']
# Out:
#                    A         B
# 2013-01-01  0.740422  0.619768
# 2013-01-02 -0.255496 -1.347615
# 2013-01-03  1.811245 -1.764546
# 2013-01-04  0.450626 -0.824448
# 2013-01-05  0.698824  1.130257
# 2013-01-06 -0.159491  0.020443

# %%
df.iloc[3].T
# Out:
# A    0.450626
# B   -0.824448
# C   -0.624153
# D   -0.947225
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
import seaborn as sns

# %%
kashti = sns.load_dataset('titanic')
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
kashti.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 574         0       3    male  16.0      0      0   8.0500        S   Third
# 589         0       3    male   NaN      0      0   8.0500        S   Third
# 618         1       2  female   4.0      2      1  39.0000        S  Second
# 541         0       3  female   9.0      4      2  31.2750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 45          0       3    male   NaN      0      0   8.0500        S   Third
# 171         0       3    male   4.0      4      1  29.1250        Q   Third
# 296         0       3    male  23.5      0      0   7.2292        C   Third
# 749         0       3    male  31.0      0      0   7.7500        Q   Third
# 642         0       3  female   2.0      3      2  27.9000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti[kashti['age'] < 5]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 63          0       3    male  4.00      3      2   27.9000        S   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 171         0       3    male  4.00      4      1   29.1250        Q   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %%
kashti[kashti['fare'] < 5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# ...
