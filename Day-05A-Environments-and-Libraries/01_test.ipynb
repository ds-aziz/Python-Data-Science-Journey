# %% [markdown]
# #Subject of this notebook:
# #Authored by: Aziz Baloch
# #Where to contact: github profile link "OR" email (gmail) google collab
# [Lecture:5](https://www.youtube.com/watch?v=V5Pk5qvRo7A)

# %% [markdown]
# print function ko hum output lene ke liye istamal krte hai.

# %%
print("Aziz")
# Out:
# Aziz

# %% [markdown]
# input function user se data lene ke liye use hota hai.

# %%
print(input("how old are you sir? "))
# Out:
# 25

# %% [markdown]
# operators 2 ya 2 se zyada number ke bech me koi bhi function tor pr istamal kiya jaty hai ya phr koi operation krne ke liye.

# %%
print(8+4)
# Out:
# 12

# %%
name= ("Aziz","nandlal","waljee")

# %%
name
# Out:
# ('Aziz', 'nandlal', 'waljee')

# %% [markdown]
# Assignment ye hai ke python ke andar jupyter notebook ki file ko pdf me kese convert krty hai??
